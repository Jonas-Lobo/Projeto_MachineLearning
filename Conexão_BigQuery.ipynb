# %%
# !pip install db-dtypes

# %%
import pandas as pd
from google.cloud import bigquery
from google.oauth2 import service_account

# %%
import pandas_gbq
import db_dtypes

# %%
credentials = service_account.Credentials.from_service_account_file( filename='e-comerce-388402-2871624f6839.json', 
                                                                    scopes=["https://www.googleapis.com/auth/cloud-platform"]
)

# %%
query = """
    select * from Vendas.Vendas2

"""

# %%
df = pd.read_gbq(credentials=credentials,query=query)

# %%
df
# Out:
#       ID_Produto           Produto         Categoria     Segmento Fabricante  \
# 0    SKU-0000325  Morotola Moto G5         Celulares    Doméstico   Motorola
# 1    SKU-0000326  Morotola Moto G5         Celulares    Doméstico   Motorola
# 2    SKU-0000327  Morotola Moto G5         Celulares    Doméstico   Motorola
# 3    SKU-0000171  Samsung Galaxy 8         Celulares  Corporativo    Samsung
# 4    SKU-0000172  Samsung Galaxy 8         Celulares  Corporativo    Samsung
# ..           ...               ...               ...          ...        ...
# 452  SKU-0000451  Geladeira Duplex  Eletrodomésticos    Doméstico   Brastemp
# 453  SKU-0000453  Geladeira Duplex  Eletrodomésticos    Doméstico   Brastemp
# 454  SKU-0000454  Geladeira Duplex  Eletrodomésticos    Doméstico   Brastemp
# 455  SKU-0000456  Geladeira Duplex  Eletrodomésticos    Doméstico         LG
# 456  SKU-0000457  Geladeira Duplex  Eletrodomésticos    Doméstico   Brastemp
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID_Produto              457 non-null    object
#  1   Produto                 457 non-null    object
#  2   Categoria               457 non-null    object
#  3   Segmento                457 non-null    object
#  4   Fabricante              457 non-null    object
#  5   Loja                    457 non-null    object
#  6   Cidade                  457 non-null    object
#  7   Estado                  457 non-null    object
#  8   Vendedor                457 non-null    object
#  9   ID_Vendedor             457 non-null    Int64
#  10  Comiss__o__Percentual_  457 non-null    Int64
#  11  Data_Venda              457 non-null    dbdate
#  12  ValorVenda              457 non-null    Int64
#  13  Custo                   457 non-null    Int64
# ...
